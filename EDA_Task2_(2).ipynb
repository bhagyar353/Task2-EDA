# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Name": ["John","Alice","Bob","Emma","David","Sophia","Chris","Olivia","Daniel","Mia"],
    "Age": [22,25,24,23,26,27,22,24,25,23],
    "Gender": ["Male","Female","Male","Female","Male","Female","Male","Female","Male","Female"],
    "Marks": [78,85,67,90,88,76,80,95,70,84]
}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Gender  Marks
# 0    John   22    Male     78
# 1   Alice   25  Female     85
# 2     Bob   24    Male     67
# 3    Emma   23  Female     90
# 4   David   26    Male     88
# 5  Sophia   27  Female     76
# 6   Chris   22    Male     80
# 7  Olivia   24  Female     95
# 8  Daniel   25    Male     70
# 9     Mia   23  Female     84

# %%
df.head()
# Out:
#     Name  Age  Gender  Marks
# 0   John   22    Male     78
# 1  Alice   25  Female     85
# 2    Bob   24    Male     67
# 3   Emma   23  Female     90
# 4  David   26    Male     88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   Gender  10 non-null     object
#  3   Marks   10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#             Age     Marks
# count  10.00000  10.00000
# mean   24.10000  81.30000
# std     1.66333   8.83239
# min    22.00000  67.00000
# 25%    23.00000  76.50000
# 50%    24.00000  82.00000
# 75%    25.00000  87.25000
# max    27.00000  95.00000

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Gender    0
# Marks     0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Name": ["John","Alice","Bob","Emma","David","Sophia","Chris","Olivia","Daniel","Mia"],
    "Age": [22,25,24,23,26,27,22,24,25,23],
    "Gender": ["Male","Female","Male","Female","Male","Female","Male","Female","Male","Female"],
    "Marks": [78,85,67,90,88,76,80,95,70,84]
}

df = pd.DataFrame(data)

df["Marks"].hist()
plt.title("Distribution of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
df["Gender"].value_counts().plot(kind="bar")
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df["Marks"])
plt.title("Box Plot of Marks")
plt.xlabel("Marks")
plt.show()

# %% [markdown]
# Dataset contains 10 rows and 4 columns
#
# Average marks of students is around 81
#
# Female students scored slightly higher marks
#
# No missing values found in dataset
#
# Marks distribution is fairly balanced

# %%
sns.boxplot(x=df["Marks"], color="skyblue")
# Out:
# <Axes: xlabel='Marks'>
